# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense,Flatten
from tensorflow.keras.datasets import mnist #mnist ka use karke data ko load karte h
import warnings
warnings.filterwarnings("ignore")

# %%
#Load datasets 
(X_train,Y_train),(X_test,Y_test)=mnist.load_data()
print("shape of X train: ",X_train.shape)
print("shape of Y train: ",Y_train.shape)
print("shape of X test: ",X_test.shape)
print("shape of Y test: ",Y_test.shape)
# Out:
# shape of X train:  (60000, 28, 28)
# shape of Y train:  (60000,)
# shape of X test:  (10000, 28, 28)
# shape of Y test:  (10000,)

# %%
#Normalize data (hamesha features ko hi normalize kiya jata h)
X_train=X_train/255.0
X_test=X_test/255.0

# %%
#create the model(ek ke baad ek layer bane isliye sequential ka use kiye)
model=Sequential([
    Flatten(input_shape=(28,28)), #28 pixel length and 28 pixel ht h (flatten 28*28 img ko 1D array m change karta h)
    #hidden layer 1
    Dense(128,activation='relu'), #relu is rectified linear unit(agar 0 hoga to 0 ayega & agar +ve ho to +ve dega)
    #hidden layer 2
    Dense(64,activation='relu'),
    #output layer
    Dense(10,activation='softmax')
])
#softmax converts the output scores into probabilities.

# %%
#before training,tensorflow needs three things:
#optimizer:-how to update the weights.
#loss function:-how to calculate the error.
#metrices:-how to measure the model's performance.
model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.

# %%
#train the model
model.fit(X_train,Y_train,epochs=10,validation_data=(X_test,Y_test))
# Out:
# Epoch 1/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 12s 5ms/step - accuracy: 0.9278 - loss: 0.2433 - val_accuracy: 0.9496 - val_loss: 0.1596
# Epoch 2/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.9684 - loss: 0.1033 - val_accuracy: 0.9726 - val_loss: 0.0885
# Epoch 3/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.9776 - loss: 0.0722 - val_accuracy: 0.9710 - val_loss: 0.0921
# Epoch 4/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.9829 - loss: 0.0550 - val_accuracy: 0.9755 - val_loss: 0.0829
# Epoch 5/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.9856 - loss: 0.0431 - val_accuracy: 0.9744 - val_loss: 0.0853
# Epoch 6/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.9887 - loss: 0.0346 - val_accuracy: 0.9725 - val_loss: 0.0951
# Epoch 7/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.9904 - loss: 0.0282 - val_accuracy: 0.9780 - val_loss: 0.0856
# Epoch 8/10
# ...

# %%
#save the model
model.save("ann_model.keras")
print("Model is saved")
# Out:
# Model is saved

# %%
#Evaluation model
loss,accuracy=model.evaluate(X_test,Y_test)
print(f"Model Accuracy={accuracy}")
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9726 - loss: 0.1087
# Model Accuracy=0.972599983215332
